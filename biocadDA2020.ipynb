# %% [markdown]
# <center style="font-size: 26px"> <b>Проверка уровня знаний Python</b></center>

# %% [markdown]
# <center style="background-color: #23B04A; color: white; font-size: 16px"><b>NumPy</b></center>

# %%
# обеспечиваем совместимость с Python 2 и 3
from __future__ import (absolute_import, division, print_function, unicode_literals)

# отключаем предупреждения дистрибутива Anaconda
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# ### Практические задания:

# %%
# Импортируем библиотеки NumPy и Pandas - при каждом запуске тетрадки, библиотеки нужно вновь импортировать
import numpy as np
import pandas as pd

# %% [markdown]
# #### 1. Создание массивов
# Создайте и перемножьте одномерный и двумерный массивы при помощи библиотеки NumPy

# %%
a = np.array([1, 2, 3]) # создание одномерного массива
b = np.array([[4, 5, 6], [7, 8, 8]]) # создание двумерного массива
a*b # перемножение массивов
# Out:
# array([[ 4, 10, 18],
#        [ 7, 16, 24]])

# %% [markdown]
# #### 2. Методы создания массивов
# Создайте один и тот же массив 3-мя разными способами при помощи библиотеки NumPy

# %%
arr1 = np.array([1,2,3,4,5]) # просто создаём массив от 1 до 5
arr2 = np.arange(1,6,1) # создаём массив от 1 до 6 (не включительно) с шагом 1
arr3 = np.linspace(1, 5, 5, dtype=int) # определяем массив от 1 до 5 с количеством значений 5, а также приводим к типу int
arr4 = arr1.copy() # создаём массив путём копирования массива arr1

# arr3 = np.linspace(1, 5, 5)
# out: [1.,2.,3.,4.,5.]

# %% [markdown]
# #### 3. Индексирование массивов
#
# Напишите код, производящий указанные в комментариях операции с массивами

# %%
a = np.diag(np.arange(3))  # Выделите значение = 1
# очевидно, что данный код создаёт массив типа [[0, 0, 0],[0, 1, 0],[0, 0, 2]], так что можно обратиться по индексу
a[1][1]
# ВАШ КОД ЗДЕСЬ

b = np.random.rand(5, 5)  # Выделите первую строку
# индексация в массивах numpy тоже начинается с нуля
b[0]

c = np.arange(10) # Присвойте значение = 25 элементам массива с 3 по 6 включительно
# осуществляем обычный срез с присваинием значений, помня, что питон не включает правое значение
c[3:7] = 25

# %% [markdown]
# #### 4. Индексирование масками
#
# Выберите из предоставленного массива значения, делящиеся на 3 без остатка, и присвойте им значение = 10

# %%
np.random.seed(3)
a = np.random.random_integers(0, 20, 15)  # предоставленный массив
print(a) # печать исходного массива для сравнения
a[(a%3==0)] = 10 # условие деления на 3 без остатка
print(a) # результат
# Out:
# [10  3  8  0 19 10 11  9 10  6  0 20 12  7 14]
# [10 10  8 10 19 10 11 10 10 10 10 20 10  7 14]

# %% [markdown]
# #### 5. Меры центральной тенденции и меры вариации
#
# Напишите код, находящий указанные в комментариях значения

# %%
a = np.linspace(0, 20, 5)  # Найти среднее арифметическое массива
np.mean(a)

b = np.linspace(0, 30, 10)  # Найти медианное значение массива
np.median(b)

c = np.linspace(0, 10, 10)  # Найти кумулятивную сумму элементов массива
np.cumsum(c)
# Out:
# array([ 0.        ,  1.11111111,  3.33333333,  6.66666667, 11.11111111,
#        16.66666667, 23.33333333, 31.11111111, 40.        , 50.        ])

# %% [markdown]
# <center style="background-color: #23B04A; color: white; font-size: 16px"><b>Pandas</b></center>

# %% [markdown]
# #### 6. Чтение и первичная информация о файле
# Выведите первые 15 значений (строк) получившегося датафрейма

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', header=None)
df.columns = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 
'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'salary']

df.head(15)
# Out:
#     age          workclass  fnlwgt      education  education-num  \
# 0    39          State-gov   77516      Bachelors             13
# 1    50   Self-emp-not-inc   83311      Bachelors             13
# 2    38            Private  215646        HS-grad              9
# 3    53            Private  234721           11th              7
# 4    28            Private  338409      Bachelors             13
# 5    37            Private  284582        Masters             14
# 6    49            Private  160187            9th              5
# 7    52   Self-emp-not-inc  209642        HS-grad              9
# 8    31            Private   45781        Masters             14
# 9    42            Private  159449      Bachelors             13
# 10   37            Private  280464   Some-college             10
# 11   30          State-gov  141297      Bachelors             13
# 12   23            Private  122272      Bachelors             13
# 13   32            Private  205019     Assoc-acdm             12
# 14   40            Private  121772      Assoc-voc             11
#
#             marital-status          occupation    relationship  \
# 0            Never-married        Adm-clerical   Not-in-family
# 1       Married-civ-spouse     Exec-managerial         Husband
# 2                 Divorced   Handlers-cleaners   Not-in-family
# 3       Married-civ-spouse   Handlers-cleaners         Husband
# 4       Married-civ-spouse      Prof-specialty            Wife
# 5       Married-civ-spouse     Exec-managerial            Wife
# 6    Married-spouse-absent       Other-service   Not-in-family
# 7       Married-civ-spouse     Exec-managerial         Husband
# 8            Never-married      Prof-specialty   Not-in-family
# 9       Married-civ-spouse     Exec-managerial         Husband
# 10      Married-civ-spouse     Exec-managerial         Husband
# 11      Married-civ-spouse      Prof-specialty         Husband
# 12           Never-married        Adm-clerical       Own-child
# 13           Never-married               Sales   Not-in-family
# 14      Married-civ-spouse        Craft-repair         Husband
#
#                    race      sex  capital-gain  capital-loss  hours-per-week  \
# 0                 White     Male          2174             0              40
# 1                 White     Male             0             0              13
# 2                 White     Male             0             0              40
# 3                 Black     Male             0             0              40
# 4                 Black   Female             0             0              40
# 5                 White   Female             0             0              40
# 6                 Black   Female             0             0              16
# 7                 White     Male             0             0              45
# 8                 White   Female         14084             0              50
# 9                 White     Male          5178             0              40
# 10                Black     Male             0             0              80
# 11   Asian-Pac-Islander     Male             0             0              40
# 12                White   Female             0             0              30
# 13                Black     Male             0             0              50
# 14   Asian-Pac-Islander     Male             0             0              40
#
#     native-country  salary
# 0    United-States   <=50K
# 1    United-States   <=50K
# 2    United-States   <=50K
# 3    United-States   <=50K
# 4             Cuba   <=50K
# 5    United-States   <=50K
# 6          Jamaica   <=50K
# 7    United-States    >50K
# 8    United-States    >50K
# 9    United-States    >50K
# 10   United-States    >50K
# 11           India    >50K
# 12   United-States   <=50K
# 13   United-States   <=50K
# 14               ?    >50K

# %% [markdown]
# Каждая строка данного фрейма - это участник социологического опроса, проведённого в Америке

# %% [markdown]
# #### 7. Индексация с условием
# Вынесите в новый датафрейм с названием df_work мужчин (признак *sex*) старше 35 (признак *age*)

# %%
# не работает эта конструкция, и я не знаю почему, хотя работал аналог всегда
df_work = df[(df.age > 35) & (df.sex == 'Male')]
df_work
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, salary]
# Index: []

# %% [markdown]
# #### 8. Группировка и меры центральной тенденции
# Сгруппируйте всех опрошенных по уровню образования (признак *education*) и найдите среднее значение по каждому из числовых (type = int) столбцов в каждой из получившихся групп

# %%
# группировка по уровню образования - groupby + mean для поиска среднего значения
df_gb = df.groupby('education').mean()
df_gb
# Out:
#                      age         fnlwgt  education-num  capital-gain  \
# education
#  10th          37.429796  196832.465166            6.0    404.574491
#  11th          32.355745  194928.077447            7.0    215.097872
#  12th          32.000000  199097.508083            8.0    284.087760
#  1st-4th       46.142857  239303.000000            2.0    125.875000
#  5th-6th       42.885886  232448.333333            3.0    176.021021
#  7th-8th       48.445820  188079.171827            4.0    233.939628
#  9th           41.060311  202485.066148            5.0    342.089494
#  Assoc-acdm    37.381443  193424.093721           12.0    640.399250
#  Assoc-voc     38.553546  181936.016643           11.0    715.051375
#  Bachelors     38.904949  188055.914846           13.0   1756.299533
#  Doctorate     47.702179  186698.760291           16.0   4770.145278
#  HS-grad       38.974479  189538.739739            9.0    576.800114
#  Masters       44.049913  179852.362739           14.0   2562.563552
#  Preschool     42.764706  235889.372549            1.0    898.392157
#  Prof-school   44.746528  185663.706597           15.0  10414.416667
#  Some-college  35.756275  188742.922370           10.0    598.824167
#
#                capital-loss  hours-per-week
# education
#  10th             56.845659       37.052519
#  11th             50.079149       33.925957
#  12th             32.337182       35.780600
#  1st-4th          48.327381       38.255952
#  5th-6th          68.252252       38.897898
#  7th-8th          65.668731       39.366873
#  9th              28.998054       38.044747
#  Assoc-acdm       93.418932       40.504217
#  Assoc-voc        72.754703       41.610709
#  Bachelors       118.350327       42.614006
#  Doctorate       262.845036       46.973366
#  HS-grad          70.466622       40.575374
#  Masters         166.719675       43.836332
#  Preschool        66.490196       36.647059
#  Prof-school     231.203125       47.425347
#  Some-college     71.637087       38.852284

# %% [markdown]
# #### 9. Объединения и слияния
# Объедините имеющийся датафрейм adult.data с прописанными ниже df_2 (новая колонка) и df_3 (новая строка), затем отсортируйте по признаку *age*

# %%
df_2 = pd.DataFrame({'random_column': np.random.rand(32561)})
df_3 = pd.DataFrame({'age': 40, 
                     'workclass': 'Self-emp-not-inc', 
                     'fnlwgt': 135415, 
                     'education': 'Some-college', 
                     'education-num': 10, 
                     'marital-status': 'Married-civ-spouse', 
                     'occupation': 'Other-service', 
                     'relationship': 'Wife', 
                     'race': 'White', 
                     'sex': 'Female', 
                     'capital-gain': 0, 
                     'capital-loss': 0, 
                     'hours-per-week': 5, 
                     'native-country': 'United-States', 
                     'salary': '<=50K'}, index=[32562])

df['random_column'] = df_2 # добавили колонку
df.append(df_3) # добавили строку
df.sort_values('age')
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 12318   17            Private  127366           11th              7
# 6312    17            Private  132755           11th              7
# 30927   17            Private  108470           11th              7
# 12787   17          Local-gov  308901           11th              7
# 25755   17                  ?   47407           11th              7
# ...    ...                ...     ...            ...            ...
# 24043   90   Self-emp-not-inc   82628        HS-grad              9
# 32277   90            Private  313749        HS-grad              9
# 5104    90            Private   52386   Some-college             10
# 8963    90                  ?   77053        HS-grad              9
# 10210   90   Self-emp-not-inc  282095   Some-college             10
#
#             marital-status        occupation    relationship  \
# 12318        Never-married             Sales       Own-child
# 6312         Never-married             Sales       Own-child
# 30927        Never-married     Other-service       Own-child
# 12787        Never-married      Adm-clerical       Own-child
# 25755        Never-married                 ?       Own-child
# ...                    ...               ...             ...
# 24043        Never-married   Exec-managerial   Not-in-family
# 32277              Widowed      Adm-clerical       Unmarried
# 5104         Never-married     Other-service   Not-in-family
# 8963               Widowed                 ?   Not-in-family
# 10210   Married-civ-spouse   Farming-fishing         Husband
#
#                       race      sex  capital-gain  capital-loss  \
# 12318                White   Female             0             0
# 6312                 White     Male             0             0
# 30927                Black     Male             0             0
# 12787                White   Female             0             0
# 25755                White     Male             0             0
# ...                    ...      ...           ...           ...
# 24043                White     Male          2964             0
# 32277                White   Female             0             0
# 5104    Asian-Pac-Islander     Male             0             0
# 8963                 White   Female             0          4356
# 10210                White     Male             0             0
#
#        hours-per-week  native-country  salary  random_column
# 12318               8   United-States   <=50K       0.252330
# 6312               15   United-States   <=50K       0.268009
# 30927              17   United-States   <=50K       0.177033
# 12787              15   United-States   <=50K       0.213102
# 25755              10   United-States   <=50K       0.122482
# ...               ...             ...     ...            ...
# 24043              12   United-States   <=50K       0.919460
# 32277              25   United-States   <=50K       0.270288
# 5104               35   United-States   <=50K       0.259954
# 8963               40   United-States   <=50K       0.925067
# 10210              40   United-States   <=50K       0.048957
#
# [32561 rows x 16 columns]

# %% [markdown]
# #### 10. Применение функций
# Замените каждое значение в каждом из числовых (type = int) столбцов на среднеквадратичное отклонение по этому столбцу

# %%
df.std()
# Out:
# age                   13.640433
# fnlwgt            105549.977697
# education-num          2.572720
# capital-gain        7385.292085
# capital-loss         402.960219
# hours-per-week        12.347429
# random_column          0.288985
# dtype: float64

# %% [markdown]
# <center style="background-color: #23B04A; color: white; font-size: 16px"><b>EDA по доходу населения UCI Adult</b></center>

# %% [markdown]
# ### Практические задания:

# %% [markdown]
# #### Обновляем файл adult.data.csv и решаем задания ниже на нём

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', header=None)
df.columns = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 
'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'salary']

# %% [markdown]
# Уникальные значения признаков в датафрейме:
# - age: continuous.
# - workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# - fnlwgt: continuous.
# - education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# - education-num: continuous.
# - marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# - occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# - relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# - race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# - sex: Female, Male.
# - capital-gain: continuous.
# - capital-loss: continuous.
# - hours-per-week: continuous.
# - native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.
# - salary: >50K,<=50K

# %% [markdown]
# #### 11. Каков средний возраст (признак *age*) мужчин?

# %%
df.groupby('sex')[['age']].mean()
# Out:
#                age
# sex
#  Female  36.858230
#  Male    39.433547

# %% [markdown]
# **12. Каковы средние значения и среднеквадратичные отклонения возраста тех, кто получает более 50K в год (признак *salary*) и тех, кто получает менее 50K в год?**

# %%
data_mean = df.groupby('salary')[['age']].mean() 
data_std = df.groupby('salary')[['age']].std()
 
d = pd.concat([data_mean,data_std],axis=1)
d.columns = ['mean','std']
d
# Out:
#              mean        std
# salary
#  <=50K  36.783738  14.020088
#  >50K   44.249841  10.519028

# %% [markdown]
# **13. Найдите таким образом максимальный возраст мужчин расы *Amer-Indian-Eskimo*.**

# %%
df[df['sex'].str.contains('Male') & df['race'].str.contains('Amer-Indian-Eskimo')]['age'].max()

# df.groupby(['race', 'sex'])['age'].describe()
# Out:
# 82

# %% [markdown]
# **14. Какое максимальное число часов человек работает в неделю (признак *hours-per-week*)? Сколько людей работают такое количество часов и каков среди них процент зарабатывающих много (*salary* >50k)?**

# %%
max_hours = df['hours-per-week'].max() # 99
max_hours_people = df[df['hours-per-week'] == 99] # 85

# %%
df[(df['hours-per-week'] == 99 & df['salary'].str.contains('>50K'))].count() # 2
# Out:
# age               2
# workclass         2
# fnlwgt            2
# education         2
# education-num     2
# marital-status    2
# occupation        2
# relationship      2
# race              2
# sex               2
# capital-gain      2
# capital-loss      2
# hours-per-week    2
# native-country    2
# salary            2
# dtype: int64

# %%
2/85 # 2.35%
# Out:
# 0.023529411764705882

# %% [markdown]
# **15. Посчитайте среднее время работы (*hours-per-week*) зарабатывающих мало и много (*salary*) для каждой страны (*native-country*).**

# %%
df['hours-per-week'].describe()
# Out:
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000
# Name: hours-per-week, dtype: float64

# %%
df.groupby(['salary', 'native-country'])['hours-per-week'].describe()
# Out:
#                           count       mean        std   min    25%   50%  \
# salary native-country
#  <=50K  ?                 437.0  40.164760  12.817002   1.0  40.00  40.0
#         Cambodia           12.0  41.416667   3.088346  40.0  40.00  40.0
#         Canada             82.0  37.914634  13.012056   8.0  32.75  40.0
#         China              55.0  37.381818  11.439844   1.0  36.00  40.0
#         Columbia           57.0  38.684211   8.610952   5.0  40.00  40.0
# ...                         ...        ...        ...   ...    ...   ...
#  >50K   Thailand            3.0  58.333333  14.433757  50.0  50.00  50.0
#         Trinadad&Tobago     2.0  40.000000   0.000000  40.0  40.00  40.0
#         United-States    7171.0  45.505369  11.025092   1.0  40.00  40.0
#         Vietnam             5.0  39.200000   1.788854  36.0  40.00  40.0
#         Yugoslavia          6.0  49.500000  11.202678  40.0  40.00  46.0
#
#                           75%   max
# salary native-country
#  <=50K  ?                45.0  99.0
#         Cambodia         40.5  50.0
#         Canada           40.0  70.0
#         China            40.0  60.0
#         Columbia         40.0  60.0
# ...                       ...   ...
#  >50K   Thailand         62.5  75.0
#         Trinadad&Tobago  40.0  40.0
#         United-States    50.0  99.0
#         Vietnam          40.0  40.0
#         Yugoslavia       58.0  65.0
#
# [82 rows x 8 columns]

# %% [markdown]
# <center style="background-color: #23B04A; color: white; font-size: 16px"><b>Анализ данных по доходу населения UCI Adult</b></center>

# %% [markdown]
# Попробуйте написать модель, предсказывающую уровень дохода ('salary') людей на основе датасета UCI Adult.
#
# Напишите код:
# - для подготовки данных,
# - для обучения модели (одной или нескольких - решать Вам),
# - для оценки качества модели.
#
# Итоговый результат - модель + получившиеся метрики качества.

# %% [markdown]
# #### Несколько примечаний:
#
# * Random Forest. Почему? Во-первых все так делают, а во-вторых, он не требует расширения признаков, устойчив к масштабу значений признаков и рассчитывается быстро.
#
# * Поскольку текстовые данные плохо сочетаются с алгоритмами машинного обучения, нужно преобразовать нечисловые данные в числовые.

# %%
import re

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xgboost as xgb
import seaborn as sns

from sklearn import metrics
from sklearn.metrics import confusion_matrix

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier

from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.feature_selection import SelectKBest, f_classif

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', header=None)
df.columns = ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status', 'occupation', 'relationship', 'race', 'sex', 
'capital_gain', 'capital_loss', 'hours_per_week', 'native_country', 'salary']

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  salary
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
df.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# salary            0
# dtype: int64

# %%
df.nunique()
# Out:
# age                  73
# workclass             9
# fnlwgt            21648
# education            16
# education_num        16
# marital_status        7
# occupation           15
# relationship          6
# race                  5
# sex                   2
# capital_gain        119
# capital_loss         92
# hours_per_week       94
# native_country       42
# salary                2
# dtype: int64

# %%
df['sex'] = LabelEncoder().fit_transform(df['sex'])

# %%
dfdum = pd.get_dummies(df, prefix='wc_', columns=['workclass'])
dfdum = pd.get_dummies(dfdum, prefix='edu_', columns=['education'])
dfdum = pd.get_dummies(dfdum, prefix='marstat_', columns=['marital_status'])
dfdum = pd.get_dummies(dfdum, prefix='occup_', columns=['occupation'])
dfdum = pd.get_dummies(dfdum, prefix='relship_', columns=['relationship'])
dfdum = pd.get_dummies(dfdum, prefix='race_', columns=['race'])
dfdum = pd.get_dummies(dfdum, prefix='natcoun_', columns=['native_country'])
dfdum = dfdum.replace({'salary': '<=50K'}, {'salary': 0}, regex=True)
dfdum = dfdum.replace({'salary': '>50K'}, {'salary': 1}, regex=True)
dfdum
# Out:
#        age  fnlwgt  education_num  sex  capital_gain  capital_loss  \
# 0       39   77516             13    1          2174             0
# 1       50   83311             13    1             0             0
# 2       38  215646              9    1             0             0
# 3       53  234721              7    1             0             0
# 4       28  338409             13    0             0             0
# ...    ...     ...            ...  ...           ...           ...
# 32556   27  257302             12    0             0             0
# 32557   40  154374              9    1             0             0
# 32558   58  151910              9    0             0             0
# 32559   22  201490              9    1             0             0
# 32560   52  287927              9    0         15024             0
#
#        hours_per_week  salary  wc__ ?  wc__ Federal-gov  ...  \
# 0                  40       0       0                 0  ...
# 1                  13       0       0                 0  ...
# 2                  40       0       0                 0  ...
# 3                  40       0       0                 0  ...
# 4                  40       0       0                 0  ...
# ...               ...     ...     ...               ...  ...
# 32556              38       0       0                 0  ...
# 32557              40       1       0                 0  ...
# 32558              40       0       0                 0  ...
# 32559              20       0       0                 0  ...
# 32560              40       1       0                 0  ...
#
#        natcoun__ Portugal  natcoun__ Puerto-Rico  natcoun__ Scotland  \
# 0                       0                      0                   0
# 1                       0                      0                   0
# 2                       0                      0                   0
# 3                       0                      0                   0
# 4                       0                      0                   0
# ...                   ...                    ...                 ...
# 32556                   0                      0                   0
# 32557                   0                      0                   0
# 32558                   0                      0                   0
# 32559                   0                      0                   0
# 32560                   0                      0                   0
#
#        natcoun__ South  natcoun__ Taiwan  natcoun__ Thailand  \
# 0                    0                 0                   0
# 1                    0                 0                   0
# 2                    0                 0                   0
# 3                    0                 0                   0
# 4                    0                 0                   0
# ...                ...               ...                 ...
# 32556                0                 0                   0
# 32557                0                 0                   0
# 32558                0                 0                   0
# 32559                0                 0                   0
# 32560                0                 0                   0
#
#        natcoun__ Trinadad&Tobago  natcoun__ United-States  natcoun__ Vietnam  \
# 0                              0                        1                  0
# 1                              0                        1                  0
# 2                              0                        1                  0
# 3                              0                        1                  0
# 4                              0                        0                  0
# ...                          ...                      ...                ...
# 32556                          0                        1                  0
# 32557                          0                        1                  0
# 32558                          0                        1                  0
# 32559                          0                        1                  0
# 32560                          0                        1                  0
#
#        natcoun__ Yugoslavia
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# 4                         0
# ...                     ...
# 32556                     0
# 32557                     0
# 32558                     0
# 32559                     0
# 32560                     0
#
# [32561 rows x 108 columns]

# %%
#Training data
train_data = dfdum
feature_train = train_data['salary']
label_train = train_data.drop(['salary'], axis = 1)

# %%
# Data to be predicted
X_to_be_predicted = dfdum[dfdum.salary.isnull()]
X_to_be_predicted = X_to_be_predicted.drop(['salary'], axis = 1)

# %%
##Random forest
clf = RandomForestClassifier(criterion='entropy',n_estimators=700,min_samples_split=10,min_samples_leaf=1,max_features='auto',
                             oob_score=True, random_state=1, n_jobs=-1)

x_train, x_test, y_train, y_test = train_test_split(label_train, feature_train, test_size=0.2)
clf.fit(x_train, np.ravel(y_train))

print("RF Accuracy: "+repr(round(clf.score(x_test, y_test) * 100, 2)) + "%")

result_rf=cross_val_score(clf,x_train,y_train,cv=10,scoring='accuracy')

print('The cross validated score for Random forest is:',round(result_rf.mean()*100,2))

y_pred = cross_val_predict(clf,x_train,y_train,cv=10)

sns.heatmap(confusion_matrix(y_train,y_pred),annot=True,fmt='3.0f',cmap="summer")
plt.title('Confusion_matrix for RF', y=1.05, size=15)
# Out:
# RF Accuracy: 86.04%
# The cross validated score for Random forest is: 86.31
# Text(0.5, 1.05, 'Confusion_matrix for RF')

# %%
##Gaussian
clf = GaussianNB()
x_train, x_test, y_train, y_test = train_test_split(label_train, feature_train, test_size=0.2)
clf.fit(x_train, np.ravel(y_train))
print("NB Accuracy: "+repr(round(clf.score(x_test, y_test) * 100, 2)) + "%")
result_rf=cross_val_score(clf,x_train,y_train,cv=10,scoring='accuracy')
print('The cross validated score for Random forest is:',round(result_rf.mean()*100,2))
y_pred = cross_val_predict(clf,x_train,y_train,cv=10)
sns.heatmap(confusion_matrix(y_train,y_pred),annot=True,fmt='3.0f',cmap="summer")
plt.title('Confusion_matrix for NB', y=1.05, size=15)
# Out:
# NB Accuracy: 79.26%
# The cross validated score for Random forest is: 79.55
# Text(0.5, 1.05, 'Confusion_matrix for NB')

# %%
predictors = list(dfdum.columns.values)

# %%
##SelectKBest
selector = SelectKBest(f_classif, k=5)
selector.fit(dfdum[predictors], dfdum["salary"])

scores = -np.log10(selector.pvalues_)

plt.bar(range(len(predictors)), scores)
plt.xticks(range(len(predictors)), predictors, rotation='vertical')
plt.show()
